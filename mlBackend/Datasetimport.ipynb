# %%
# !pip install -q kaggle

# %%
import json

kaggle_username = "RKusydfe43"
kaggle_key = "KGAT_58dda0080d2ac04473382814723e24ce"

kaggle_config = {
    "username": kaggle_username,
    "key": kaggle_key
}

with open("kaggle.json", "w") as f:
    json.dump(kaggle_config, f)

# %%
import os
import shutil

os.makedirs("/root/.kaggle", exist_ok=True)
shutil.move("kaggle.json", "/root/.kaggle/kaggle.json")
os.chmod("/root/.kaggle/kaggle.json", 600)

# %%
# !kaggle datasets download -d tawsifurrahman/covid19-radiography-database
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database
# License(s): copyright-authors
# ...
# 100% 778M/778M [00:03<00:00, 204MB/s]

# %%
import zipfile
import os

zip_path = "covid19-radiography-database.zip"
extract_path = "/content/drive/MyDrive/dataset/covid19-radiography-database"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 157M/157M [00:00<00:00, 171MB/s]

# %%
import zipfile
import os

zip_path = "brain-tumor-mri-dataset.zip"
extract_path = "/content/drive/MyDrive/dataset/brain-tumor-mri-dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# !kaggle datasets download -d alifrahman/chestxraydataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/alifrahman/chestxraydataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 1.14G/1.14G [00:10<00:00, 112MB/s]

# %%
import zipfile
import os

zip_path = "chestxraydataset.zip"
extract_path = "/content/drive/MyDrive/dataset/chest-xray-dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_542/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# ...
