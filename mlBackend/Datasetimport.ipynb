# %%
# !pip install -q kaggle

# %%
import json

kaggle_username = "RKusydfe43"
kaggle_key = "KGAT_58dda0080d2ac04473382814723e24ce"

kaggle_config = {
    "username": kaggle_username,
    "key": kaggle_key
}

with open("kaggle.json", "w") as f:
    json.dump(kaggle_config, f)

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

os.makedirs("/root/.kaggle", exist_ok=True)
shutil.move("kaggle.json", "/root/.kaggle/kaggle.json")
os.chmod("/root/.kaggle/kaggle.json", 600)

# %%
# !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# brain-tumor-mri-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

zip_path = "brain-tumor-mri-dataset.zip"
extract_path = "/content/drive/MyDrive/dataset/brain-tumor-mri-dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/alifrahman/chestxraydataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# chestxraydataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

zip_path = "chestxraydataset.zip"
extract_path = "/content/drive/MyDrive/dataset/chest-xray-dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# !kaggle datasets download -d iarunava/cell-images-for-detecting-malaria
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/iarunava/cell-images-for-detecting-malaria
# License(s): unknown
# ...
# 100% 675M/675M [00:07<00:00, 98.4MB/s]

# %%
import zipfile
import os

zip_path = "cell-images-for-detecting-malaria.zip"
extract_path = "/content/drive/MyDrive/cell-images-for-detecting-malaria"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")

# %%
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 5.20G/5.20G [00:42<00:00, 131MB/s]

# %%
import zipfile
import os

zip_path = "skin-cancer-mnist-ham10000.zip"
extract_path = "/content/drive/MyDrive/dataset/skin-cancer-mnist-ham10000"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# !kaggle datasets download -d aryashah2k/breast-ultrasound-images-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/aryashah2k/breast-ultrasound-images-dataset
# License(s): CC0-1.0
# ...
# 100% 195M/195M [00:01<00:00, 186MB/s]

# %%
import zipfile
import os

zip_path = "breast-ultrasound-images-dataset.zip"
extract_path = "/content/drive/MyDrive/dataset/breast-ultrasound"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
# !kaggle datasets download -d orvile/bone-fracture-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/orvile/bone-fracture-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 319M/319M [00:02<00:00, 122MB/s]

# %%
import zipfile
import os

zip_path = "bone-fracture-dataset.zip"
extract_path = "/content/drive/MyDrive/dataset/bone-fracture-dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!
